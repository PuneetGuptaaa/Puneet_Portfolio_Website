# %%
#Import the Libraries
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusting the configuration of the plots we will create

#Read the data
df = pd.read_csv(r'C:\Users\punee\OneDrive\Documents\Datasets\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
for col in df.columns:
    missing = np.mean(df[col].isnull())
    print(missing)
# Out:
# 0.0
# 0.010041731872717789
# 0.0
# 0.0
# 0.0002608242044861763
# 0.0003912363067292645
# 0.0003912363067292645
# 0.0
# 0.0003912363067292645
# 0.00013041210224308815
# 0.0003912363067292645
# 0.2831246739697444
# 0.02464788732394366
# 0.002217005738132499
# 0.0005216484089723526

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Change the data type

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382    162.0           29
# 7445  1470       47  356000000  2797501328      983    181.0           39
# 3045  1073       47  200000000  2201647264     1382    194.0           17
# 6663   356       47  245000000  2069521700      945    138.0           35
# 7244  1470       47  321000000  2048359754      983    149.0           38

# %%
# create correct year column
df['yearcorrect'] = df['year'].astype(str).str[:4]

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382    162.0           29
# 7445  1470       47  356000000  2797501328      983    181.0           39
# 3045  1073       47  200000000  2201647264     1382    194.0           17
# 6663   356       47  245000000  2069521700      945    138.0           35
# 7244  1470       47  321000000  2048359754      983    149.0           38

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False).head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382    162.0           29
# 7445  1470       47  356000000  2797501328      983    181.0           39
# 3045  1073       47  200000000  2201647264     1382    194.0           17
# 6663   356       47  245000000  2069521700      945    138.0           35
# 7244  1470       47  321000000  2048359754      983    149.0           38

# %%
pd.set_option('display.max_rows', None)

# %%
#drop as duplicates

df.drop_duplicates().head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382    162.0           29
# 7445  1470       47  356000000  2797501328      983    181.0           39
# 3045  1073       47  200000000  2201647264     1382    194.0           17
# 6663   356       47  245000000  2069521700      945    138.0           35
# 7244  1470       47  321000000  2048359754      983    149.0           38

# %%
#scatter plot budget vs gross revenue

plt.scatter(x=df['budget'],y=df['gross'])

plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget of Movies')
plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime yearcorrect
# 0   46998772        Warner Bros.    146.0        1980
# 1   58853106   Columbia Pictures    104.0        1980
# 2  538375067           Lucasfilm    124.0        1980
# 3   83453539  Paramount Pictures     88.0        1980
# 4   39846344      Orion Pictures     98.0        1980

# %%
#plot the budget vs gross using seaborn

sns.regplot(x='budget',y='gross',data=df,scatter_kws={'color':'red'},line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# lets start looking at correlations
df.corr(method='pearson')  #pearson , kendall , spearman
# Out:
# C:\Users\punee\AppData\Local\Temp\ipykernel_21864\4278171647.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')  #pearson , kendall , spearman
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
#high corr betwween budget and correlation

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot =True)
plt.title('Correlation Matrix for Numeric Factors')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# C:\Users\punee\AppData\Local\Temp\ipykernel_21864\2693371779.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
#Looks at the company

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime yearcorrect
# 0   46998772        Warner Bros.    146.0        1980
# 1   58853106   Columbia Pictures    104.0        1980
# 2  538375067           Lucasfilm    124.0        1980
# 3   83453539  Paramount Pictures     88.0        1980
# 4   39846344      Orion Pictures     98.0        1980

# %%
#Numerizing all the variables
df_numerized = df

for col_name in df_numarized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382    162.0           29
# 7445  1470       47  356000000  2797501328      983    181.0           39
# 3045  1073       47  200000000  2201647264     1382    194.0           17
# 6663   356       47  245000000  2069521700      945    138.0           35
# 7244  1470       47  321000000  2048359754      983    149.0           38

# %%
df = df.sort_values(by=['gross'],inplace=False,ascending=False)

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382    162.0           29
# 7445  1470       47  356000000  2797501328      983    181.0           39
# 3045  1073       47  200000000  2201647264     1382    194.0           17
# 6663   356       47  245000000  2069521700      945    138.0           35
# 7244  1470       47  321000000  2048359754      983    149.0           38

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot =True)
plt.title('Correlation Matrix for Numeric Factors')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross        0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# company      0.021697 -0.092357 -0.071334 -0.014333 -0.002407  0.020656
# runtime      0.010850  0.140792 -0.059237  0.075077  0.008975  0.414068
# yearcorrect  0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
#
#                 votes  director    writer      star   country    budget  \
# name         0.012615  0.015246  0.012880 -0.006882 -0.025490  0.023392
# rating       0.006031  0.014656 -0.003149  0.009196  0.008230 -0.203946
# genre       -0.135990 -0.008553  0.017578  0.003341 -0.009164 -0.368523
# year         0.206021 -0.038354 -0.025908 -0.032157 -0.066748  0.327722
# released     0.028833  0.002308  0.008072  0.015706 -0.017228  0.019952
# score        0.474256  0.005413  0.012843  0.007296 -0.043051  0.072001
# votes        1.000000 -0.010376 -0.005316 -0.017638  0.041551  0.439675
# director    -0.010376  1.000000  0.261735  0.036593  0.011133 -0.009662
# writer      -0.005316  0.261735  1.000000  0.018520  0.022488 -0.039466
# star        -0.017638  0.036593  0.018520  1.000000 -0.009990 -0.021473
# country      0.041551  0.011133  0.022488 -0.009990  1.000000  0.052977
# budget       0.439675 -0.009662 -0.039466 -0.021473  0.052977  1.000000
# gross        0.614751 -0.029560 -0.035885 -0.000004  0.060078  0.740247
# company      0.118470 -0.008223 -0.003697  0.014082  0.048569  0.170235
# runtime      0.352303  0.017433 -0.017561  0.010108 -0.034477  0.318695
# yearcorrect  0.206021 -0.038354 -0.025908 -0.032157 -0.066748  0.327722
#
#                 gross   company   runtime  yearcorrect
# name         0.005639  0.021697  0.010850     0.025542
# rating      -0.181906 -0.092357  0.140792     0.019499
# genre       -0.244101 -0.071334 -0.059237    -0.073167
# year         0.274321 -0.014333  0.075077     1.000000
# released     0.008501 -0.002407  0.008975    -0.001740
# score        0.222556  0.020656  0.414068     0.056386
# votes        0.614751  0.118470  0.352303     0.206021
# director    -0.029560 -0.008223  0.017433    -0.038354
# writer      -0.035885 -0.003697 -0.017561    -0.025908
# star        -0.000004  0.014082  0.010108    -0.032157
# country      0.060078  0.048569 -0.034477    -0.066748
# budget       0.740247  0.170235  0.318695     0.327722
# gross        1.000000  0.149553  0.275796     0.274321
# company      0.149553  1.000000  0.037585    -0.014333
# runtime      0.275796  0.037585  1.000000     0.075077
# yearcorrect  0.274321 -0.014333  0.075077     1.000000

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              yearcorrect    0.025542
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.018083
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
#              star           0.009196
#              country        0.008230
#              budget        -0.203946
#              gross         -0.181906
#              company       -0.092357
#              runtime        0.140792
#              yearcorrect    0.019499
# genre        name           0.010996
#              rating         0.147796
#              genre          1.000000
#              year          -0.073167
#              released       0.022142
#              score          0.035106
#              votes         -0.135990
#              director      -0.008553
#              writer         0.017578
#              star           0.003341
#              country       -0.009164
#              budget        -0.368523
#              gross         -0.244101
#              company       -0.071334
#              runtime       -0.059237
#              yearcorrect   -0.073167
# year         name           0.025542
#              rating         0.019499
#              genre         -0.073167
#              year           1.000000
#              released      -0.001740
#              score          0.056386
#              votes          0.206021
#              director      -0.038354
#              writer        -0.025908
#              star          -0.032157
#              country       -0.066748
#              budget         0.327722
#              gross          0.274321
#              company       -0.014333
#              runtime        0.075077
#              yearcorrect    1.000000
# released     name          -0.006152
#              rating         0.018083
#              genre          0.022142
#              year          -0.001740
#              released       1.000000
#              score          0.045874
#              votes          0.028833
#              director       0.002308
#              writer         0.008072
#              star           0.015706
#              country       -0.017228
#              budget         0.019952
#              gross          0.008501
#              company       -0.002407
#              runtime        0.008975
#              yearcorrect   -0.001740
# score        name           0.014450
#              rating         0.065983
#              genre          0.035106
#              year           0.056386
#              released       0.045874
#              score          1.000000
#              votes          0.474256
#              director       0.005413
#              writer         0.012843
#              star           0.007296
#              country       -0.043051
#              budget         0.072001
#              gross          0.222556
#              company        0.020656
#              runtime        0.414068
#              yearcorrect    0.056386
# votes        name           0.012615
#              rating         0.006031
#              genre         -0.135990
#              year           0.206021
#              released       0.028833
#              score          0.474256
#              votes          1.000000
#              director      -0.010376
#              writer        -0.005316
#              star          -0.017638
#              country        0.041551
#              budget         0.439675
#              gross          0.614751
#              company        0.118470
#              runtime        0.352303
#              yearcorrect    0.206021
# director     name           0.015246
#              rating         0.014656
#              genre         -0.008553
#              year          -0.038354
#              released       0.002308
#              score          0.005413
#              votes         -0.010376
#              director       1.000000
#              writer         0.261735
#              star           0.036593
#              country        0.011133
#              budget        -0.009662
#              gross         -0.029560
#              company       -0.008223
#              runtime        0.017433
#              yearcorrect   -0.038354
# writer       name           0.012880
#              rating        -0.003149
#              genre          0.017578
#              year          -0.025908
#              released       0.008072
#              score          0.012843
#              votes         -0.005316
#              director       0.261735
#              writer         1.000000
#              star           0.018520
#              country        0.022488
#              budget        -0.039466
#              gross         -0.035885
#              company       -0.003697
#              runtime       -0.017561
#              yearcorrect   -0.025908
# star         name          -0.006882
#              rating         0.009196
#              genre          0.003341
#              year          -0.032157
#              released       0.015706
#              score          0.007296
#              votes         -0.017638
#              director       0.036593
#              writer         0.018520
#              star           1.000000
#              country       -0.009990
#              budget        -0.021473
#              gross         -0.000004
#              company        0.014082
#              runtime        0.010108
#              yearcorrect   -0.032157
# country      name          -0.025490
#              rating         0.008230
#              genre         -0.009164
#              year          -0.066748
#              released      -0.017228
#              score         -0.043051
#              votes          0.041551
#              director       0.011133
#              writer         0.022488
#              star          -0.009990
#              country        1.000000
#              budget         0.052977
#              gross          0.060078
#              company        0.048569
#              runtime       -0.034477
#              yearcorrect   -0.066748
# budget       name           0.023392
#              rating        -0.203946
#              genre         -0.368523
#              year           0.327722
#              released       0.019952
#              score          0.072001
#              votes          0.439675
#              director      -0.009662
#              writer        -0.039466
#              star          -0.021473
#              country        0.052977
#              budget         1.000000
#              gross          0.740247
#              company        0.170235
#              runtime        0.318695
#              yearcorrect    0.327722
# gross        name           0.005639
#              rating        -0.181906
#              genre         -0.244101
#              year           0.274321
#              released       0.008501
#              score          0.222556
#              votes          0.614751
#              director      -0.029560
#              writer        -0.035885
#              star          -0.000004
#              country        0.060078
#              budget         0.740247
#              gross          1.000000
#              company        0.149553
#              runtime        0.275796
#              yearcorrect    0.274321
# company      name           0.021697
#              rating        -0.092357
#              genre         -0.071334
#              year          -0.014333
#              released      -0.002407
#              score          0.020656
#              votes          0.118470
#              director      -0.008223
#              writer        -0.003697
#              star           0.014082
#              country        0.048569
#              budget         0.170235
#              gross          0.149553
#              company        1.000000
#              runtime        0.037585
#              yearcorrect   -0.014333
# runtime      name           0.010850
#              rating         0.140792
#              genre         -0.059237
#              year           0.075077
#              released       0.008975
#              score          0.414068
#              votes          0.352303
#              director       0.017433
#              writer        -0.017561
#              star           0.010108
#              country       -0.034477
#              budget         0.318695
#              gross          0.275796
#              company        0.037585
#              runtime        1.000000
#              yearcorrect    0.075077
# yearcorrect  name           0.025542
#              rating         0.019499
#              genre         -0.073167
#              year           1.000000
#              released      -0.001740
#              score          0.056386
#              votes          0.206021
#              director      -0.038354
#              writer        -0.025908
#              star          -0.032157
#              country       -0.066748
#              budget         0.327722
#              gross          0.274321
#              company       -0.014333
#              runtime        0.075077
#              yearcorrect    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# genre        gross         -0.244101
# gross        genre         -0.244101
# budget       rating        -0.203946
# rating       budget        -0.203946
#              gross         -0.181906
# gross        rating        -0.181906
# genre        votes         -0.135990
# votes        genre         -0.135990
# rating       company       -0.092357
# company      rating        -0.092357
# genre        yearcorrect   -0.073167
# yearcorrect  genre         -0.073167
# genre        year          -0.073167
# year         genre         -0.073167
# company      genre         -0.071334
# genre        company       -0.071334
# country      year          -0.066748
# year         country       -0.066748
# yearcorrect  country       -0.066748
# country      yearcorrect   -0.066748
# genre        runtime       -0.059237
# runtime      genre         -0.059237
# country      score         -0.043051
# score        country       -0.043051
# writer       budget        -0.039466
# budget       writer        -0.039466
# director     year          -0.038354
# year         director      -0.038354
# yearcorrect  director      -0.038354
# director     yearcorrect   -0.038354
# gross        writer        -0.035885
# writer       gross         -0.035885
# runtime      country       -0.034477
# country      runtime       -0.034477
# star         yearcorrect   -0.032157
# yearcorrect  star          -0.032157
# star         year          -0.032157
# year         star          -0.032157
# director     gross         -0.029560
# gross        director      -0.029560
# name         rating        -0.029234
# rating       name          -0.029234
# writer       yearcorrect   -0.025908
# yearcorrect  writer        -0.025908
# writer       year          -0.025908
# year         writer        -0.025908
# country      name          -0.025490
# name         country       -0.025490
# star         budget        -0.021473
# budget       star          -0.021473
# votes        star          -0.017638
# star         votes         -0.017638
# runtime      writer        -0.017561
# writer       runtime       -0.017561
# country      released      -0.017228
# released     country       -0.017228
# company      yearcorrect   -0.014333
# yearcorrect  company       -0.014333
# company      year          -0.014333
# year         company       -0.014333
# votes        director      -0.010376
# director     votes         -0.010376
# star         country       -0.009990
# country      star          -0.009990
# director     budget        -0.009662
# budget       director      -0.009662
# genre        country       -0.009164
# country      genre         -0.009164
# director     genre         -0.008553
# genre        director      -0.008553
# director     company       -0.008223
# company      director      -0.008223
# star         name          -0.006882
# name         star          -0.006882
# released     name          -0.006152
# name         released      -0.006152
# writer       votes         -0.005316
# votes        writer        -0.005316
# writer       company       -0.003697
# company      writer        -0.003697
# rating       writer        -0.003149
# writer       rating        -0.003149
# released     company       -0.002407
# company      released      -0.002407
# yearcorrect  released      -0.001740
# released     yearcorrect   -0.001740
#              year          -0.001740
# year         released      -0.001740
# gross        star          -0.000004
# star         gross         -0.000004
# director     released       0.002308
# released     director       0.002308
# genre        star           0.003341
# star         genre          0.003341
# score        director       0.005413
# director     score          0.005413
# name         gross          0.005639
# gross        name           0.005639
# votes        rating         0.006031
# rating       votes          0.006031
# star         score          0.007296
# score        star           0.007296
# released     writer         0.008072
# writer       released       0.008072
# rating       country        0.008230
# country      rating         0.008230
# released     gross          0.008501
# gross        released       0.008501
# runtime      released       0.008975
# released     runtime        0.008975
# rating       star           0.009196
# star         rating         0.009196
# runtime      star           0.010108
# star         runtime        0.010108
# runtime      name           0.010850
# name         runtime        0.010850
#              genre          0.010996
# genre        name           0.010996
# director     country        0.011133
# country      director       0.011133
# votes        name           0.012615
# name         votes          0.012615
# score        writer         0.012843
# writer       score          0.012843
# name         writer         0.012880
# writer       name           0.012880
# star         company        0.014082
# company      star           0.014082
# name         score          0.014450
# score        name           0.014450
# rating       director       0.014656
# director     rating         0.014656
# name         director       0.015246
# director     name           0.015246
# star         released       0.015706
# released     star           0.015706
# director     runtime        0.017433
# runtime      director       0.017433
# genre        writer         0.017578
# writer       genre          0.017578
# rating       released       0.018083
# released     rating         0.018083
# writer       star           0.018520
# star         writer         0.018520
# yearcorrect  rating         0.019499
# rating       yearcorrect    0.019499
#              year           0.019499
# year         rating         0.019499
# released     budget         0.019952
# budget       released       0.019952
# company      score          0.020656
# score        company        0.020656
# company      name           0.021697
# name         company        0.021697
# genre        released       0.022142
# released     genre          0.022142
# writer       country        0.022488
# country      writer         0.022488
# budget       name           0.023392
# name         budget         0.023392
#              year           0.025542
# year         name           0.025542
# yearcorrect  name           0.025542
# name         yearcorrect    0.025542
# votes        released       0.028833
# released     votes          0.028833
# genre        score          0.035106
# score        genre          0.035106
# star         director       0.036593
# director     star           0.036593
# runtime      company        0.037585
# company      runtime        0.037585
# votes        country        0.041551
# country      votes          0.041551
# score        released       0.045874
# released     score          0.045874
# country      company        0.048569
# company      country        0.048569
# budget       country        0.052977
# country      budget         0.052977
# score        yearcorrect    0.056386
# yearcorrect  score          0.056386
# score        year           0.056386
# year         score          0.056386
# gross        country        0.060078
# country      gross          0.060078
# score        rating         0.065983
# rating       score          0.065983
# budget       score          0.072001
# score        budget         0.072001
# runtime      yearcorrect    0.075077
# yearcorrect  runtime        0.075077
# runtime      year           0.075077
# year         runtime        0.075077
# votes        company        0.118470
# company      votes          0.118470
# runtime      rating         0.140792
# rating       runtime        0.140792
#              genre          0.147796
# genre        rating         0.147796
# gross        company        0.149553
# company      gross          0.149553
#              budget         0.170235
# budget       company        0.170235
# votes        yearcorrect    0.206021
# yearcorrect  votes          0.206021
# votes        year           0.206021
# year         votes          0.206021
# score        gross          0.222556
# gross        score          0.222556
# director     writer         0.261735
# writer       director       0.261735
# year         gross          0.274321
# gross        year           0.274321
#              yearcorrect    0.274321
# yearcorrect  gross          0.274321
# runtime      gross          0.275796
# gross        runtime        0.275796
# budget       runtime        0.318695
# runtime      budget         0.318695
# yearcorrect  budget         0.327722
# budget       yearcorrect    0.327722
# year         budget         0.327722
# budget       year           0.327722
# runtime      votes          0.352303
# votes        runtime        0.352303
# score        runtime        0.414068
# runtime      score          0.414068
# votes        budget         0.439675
# budget       votes          0.439675
# score        votes          0.474256
# votes        score          0.474256
# gross        votes          0.614751
# votes        gross          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# name         name           1.000000
# company      company        1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# runtime      runtime        1.000000
# votes        votes          1.000000
# writer       writer         1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# gross        gross          1.000000
# director     director       1.000000
# yearcorrect  yearcorrect    1.000000
#              year           1.000000
# year         yearcorrect    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.4]
high_corr
# Out:
# score        runtime        0.414068
# runtime      score          0.414068
# votes        budget         0.439675
# budget       votes          0.439675
# score        votes          0.474256
# votes        score          0.474256
# gross        votes          0.614751
# votes        gross          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# name         name           1.000000
# company      company        1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# runtime      runtime        1.000000
# votes        votes          1.000000
# writer       writer         1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# gross        gross          1.000000
# director     director       1.000000
# yearcorrect  yearcorrect    1.000000
#              year           1.000000
# year         yearcorrect    1.000000
# dtype: float64

# %%
#votes and budget has a positive correlation on gross eanings
#scores andd runtime has a positive correlation on the company's earnings
